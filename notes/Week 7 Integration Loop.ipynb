# %%
# ==========================================
# WEEK 7: TRACKING THE LOCAL BOUNDARY
# ==========================================

# CHANGED: Aggregating Week 7 steps. Stagnation indicators on Function 7 are completely confirmed.
# We are getting stuck at 0.5906 across a narrow parameter cluster space.

print("--- Executing Week 7 Pipeline for All 8 Functions ---\n")

week_7_submissions = {
    1: {"X": [0.684946, 0.712658], "Y": 9.202103179198517e-8},
    2: {"X": [0.711875, 0.933750], "Y": 0.5066514957174049},
    3: {"X": [0.519375, 0.639375, 0.359375], "Y": -0.03133054003097439},
    4: {"X": [0.580313, 0.430313, 0.430313, 0.280313], "Y": -3.820594708290695},
    5: {"X": [0.229844, 0.859844, 0.889844, 0.889844], "Y": 1256.3328410909178},
    6: {"X": [0.747500, 0.177500, 0.747500, 0.717500, 0.047500], "Y": -0.71981900676434},
    7: {"X": [0.540313, 0.920313, 0.330313, 0.640313, 0.710313, 0.340313], "Y": 0.5906018411618924},
    8: {"X": [0.150156, 0.930156, 0.240156, 0.010156, 0.420156, 0.410156, 0.560156, 0.210156], "Y": 8.9755307900384}
}

for i in range(1, 9):
    X_init = np.load(f'{DATA_PATH}function_{i}_initial_inputs.npy')
    y_init = np.load(f'{DATA_PATH}function_{i}_initial_outputs.npy')
    
    past_x = np.array([hist_X[i][w] for w in range(6)])
    past_y = np.array([hist_Y[i][w] for w in range(6)])
    
    w7_x = np.array([week_7_submissions[i]["X"]])
    w7_y = np.array([week_7_submissions[i]["Y"]])
    
    X_combined = np.vstack((X
