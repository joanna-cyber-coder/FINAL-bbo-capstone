# %%
# ==========================================
# WEEK 6: MINUTE STEP REFINE RUNS
# ==========================================

# CHANGED: Slicing Week 6 arrays. Notice how high-dimensional loops are beginning to stall out 
# around identical outputs, providing tiny fractions of local exploration changes.

print("--- Executing Week 6 Pipeline for All 8 Functions ---\n")

week_6_submissions = {
    1: {"X": [0.685571, 0.712970], "Y": 7.758197044315658e-8},
    2: {"X": [0.711250, 0.932500], "Y": 0.5805743633860849},
    3: {"X": [0.519688, 0.639688, 0.359688], "Y": -0.033215189047942933},
    4: {"X": [0.580625, 0.430625, 0.430625, 0.280625], "Y": -3.826244068882193},
    5: {"X": [0.229688, 0.859688, 0.889688, 0.889688], "Y": 1253.9522507646043},
    6: {"X": [0.747188, 0.177188, 0.747188, 0.717188, 0.047188], "Y": -0.7271522583914899},
    7: {"X": [0.540625, 0.920625, 0.330625, 0.640625, 0.710625, 0.340625], "Y": 0.5878323302146485},
    8: {"X": [0.150313, 0.930313, 0.240313, 0.010313, 0.420313, 0.410313, 0.560313, 0.210313], "Y": 8.9750681155286}
}

for i in range(1, 9):
    X_init = np.load(f'{DATA_PATH}function_{i}_initial_inputs.npy')
    y_init = np.load(f'{DATA_PATH}function_{i}_initial_outputs.npy')
    
    past_x = np.array([hist_X[i][w] for w in range(5)])
    past_y = np.array([hist_Y[i][w] for w in range(5)])
    
    w6_x = np.array([week_6_submissions[i]["X"]])
    w6_y = np.array([week_6_submissions[i]["Y"]])
    
    X_combined = np.vstack((X_init, past_x, w6_x))
    y_combined = np.concatenate((y_init, past_y, w6_y))
    
    hist_X[i].append(week_6_submissions[i]["X"])
    hist_Y[i].append(week_6_submissions[i]["Y"])
    
    bounds = np.array([[0.0, 1.0]] * fn_dimensions[i])
    next_x = run_optimization_pipeline(X_combined, y_combined, bounds, n_restarts=10, xi=0.01)
    
    print(f"Function {i} ({fn_dimensions[i]}D) | Week 6 Max Y: {np.max(y_combined):.6e}")
    print(f" -> Next Suggested Target for Week 7: {np.round(next_x, 5)}\n")
