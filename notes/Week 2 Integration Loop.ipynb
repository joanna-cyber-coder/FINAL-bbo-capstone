# %%
# ==========================================
# WEEK 2: LOCAL TRAJECTORY BUILDING
# ==========================================

# CHANGED: Appending the Week 2 responses into our tracking dictionaries. At this point, 
# we are maintaining our hyper-local parameter settings because our scores are climbing 
# safely, but we added a validation print statement to monitor the size of the history array.

print("--- Executing Week 2 Pipeline for All 8 Functions ---\n")

week_2_submissions = {
    1: {"X": [0.704321, 0.722345], "Y": 1.2789853232981255e-10},
    2: {"X": [0.710000, 0.930000], "Y": 0.7372849568331667},
    3: {"X": [0.515000, 0.635000, 0.355], "Y": -0.036692263933674675},
    4: {"X": [0.590000, 0.440000, 0.440000, 0.290000], "Y": -4.056260211211203},
    5: {"X": [0.225000, 0.855000, 0.885000, 0.885000], "Y": 1184.0388797368498},
    6: {"X": [0.745000, 0.175000, 0.745000, 0.715000, 0.045000], "Y": -0.7200940552265773},
    7: {"X": [0.550000, 0.930000, 0.340000, 0.650000, 0.720000, 0.350000], "Y": 0.5081481907031206},
    8: {"X": [0.155000, 0.935000, 0.245000, 0.015000, 0.425000, 0.415000, 0.565000, 0.215000], "Y": 8.961015}
}

for i in range(1, 9):
    X_init = np.load(f'{DATA_PATH}function_{i}_initial_inputs.npy')
    y_init = np.load(f'{DATA_PATH}function_{i}_initial_outputs.npy')
    
    past_x = np.array([hist_X[i][w] for w in range(1)])
    past_y = np.array([hist_Y[i][w] for w in range(1)])
    
    w2_x = np.array([week_2_submissions[i]["X"]])
    w2_y = np.array([week_2_submissions[i]["Y"]])
    
    X_combined = np.vstack((X_init, past_x, w2_x))
    y_combined = np.concatenate((y_init, past_y, w2_y))
    
    hist_X[i].append(week_2_submissions[i]["X"])
    hist_Y[i].append(week_2_submissions[i]["Y"])
    
    bounds = np.array([[0.0, 1.0]] * fn_dimensions[i])
    next_x = run_optimization_pipeline(X_combined, y_combined, bounds, n_restarts=10, xi=0.01)
    
    print(f"Function {i} ({fn_dimensions[i]}D) | Week 2 Max Y: {np.max(y_combined):.6e}")
    print(f" -> Next Suggested Target for Week 3: {np.round(next_x, 5)}\n")
