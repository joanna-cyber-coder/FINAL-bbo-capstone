# %%
# ==========================================
# WEEK 4: LOCAL Radii Drill Down
# ==========================================

# CHANGED: Week 4 results added. Low dimensions have reached a solid local cluster.
# We keep our search constraints local (restarts=10) to continue extracting spatial value
# from this basin before exploring outside bounds.

print("--- Executing Week 4 Pipeline for All 8 Functions ---\n")

week_4_submissions = {
    1: {"X": [0.689321, 0.714845], "Y": 2.6096083971921097e-8},
    2: {"X": [0.715000, 0.940000], "Y": 0.5694195359758134},
    3: {"X": [0.518750, 0.638750, 0.358750], "Y": -0.029821988345119475},
    4: {"X": [0.582500, 0.432500, 0.432500, 0.282500], "Y": -3.8629297343500357},
    5: {"X": [0.228750, 0.858750, 0.888750, 0.888750], "Y": 1239.712368171596},
    6: {"X": [0.748750, 0.178750, 0.748750, 0.718750, 0.048750], "Y": -0.7626254561571828},
    7: {"X": [0.542500, 0.922500, 0.332500, 0.642500, 0.712500, 0.342500], "Y": 0.5713456690771485},
    8: {"X": [0.151250, 0.931250, 0.241250, 0.011250, 0.421250, 0.411250, 0.561250, 0.211250], "Y": 8.9722959375}
}

for i in range(1, 9):
    X_init = np.load(f'{DATA_PATH}function_{i}_initial_inputs.npy')
    y_init = np.load(f'{DATA_PATH}function_{i}_initial_outputs.npy')
    
    past_x = np.array([hist_X[i][w] for w in range(3)])
    past_y = np.array([hist_Y[i][w] for w in range(3)])
    
    w4_x = np.array([week_4_submissions[i]["X"]])
    w4_y = np.array([week_4_submissions[i]["Y"]])
    
    X_combined = np.vstack((X_init, past_x, w4_x))
    y_combined = np.concatenate((y_init, past_y, w4_y))
    
    hist_X[i].append(week_4_submissions[i]["X"])
    hist_Y[i].append(week_4_submissions[i]["Y"])
    
    bounds = np.array([[0.0, 1.0]] * fn_dimensions[i])
    next_x = run_optimization_pipeline(X_combined, y_combined, bounds, n_restarts=10, xi=0.01)
    
    print(f"Function {i} ({fn_dimensions[i]}D) | Week 4 Max Y: {np.max(y_combined):.6e}")
    print(f" -> Next Suggested Target for Week 5: {np.round(next_x, 5)}\n")
