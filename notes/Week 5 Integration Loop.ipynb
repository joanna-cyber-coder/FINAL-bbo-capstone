# %%
# ==========================================
# WEEK 5: THE COGNITIVE PLATEAU TRAP
# ==========================================

# CHANGED: Processing Week 5 inputs. Leaderboard adjustments are starting to show 
# signs of local trapping on Function 7 and Function 8. We keep exploration jitter low 
# to protect our weekly step metrics.

print("--- Executing Week 5 Pipeline for All 8 Functions ---\n")

week_5_submissions = {
    1: {"X": [0.686821, 0.713595], "Y": 5.460790998419838e-8},
    2: {"X": [0.712500, 0.935000], "Y": 0.6361096104007569},
    3: {"X": [0.519375, 0.639375, 0.359375], "Y": -0.033661142700946466},
    4: {"X": [0.581250, 0.431250, 0.431250, 0.281250], "Y": -3.8379514883872257},
    5: {"X": [0.229375, 0.859975, 0.889375, 0.889375], "Y": 1249.1864379747549},
    6: {"X": [0.746875, 0.176875, 0.746875, 0.716875, 0.046875], "Y": -0.7160957575861197},
    7: {"X": [0.541250, 0.921250, 0.331250, 0.641250, 0.711250, 0.341250], "Y": 0.5823067894331185},
    8: {"X": [0.150625, 0.930625, 0.240625, 0.010625, 0.420625, 0.410625, 0.560625, 0.210625], "Y": 8.974147109375}
}

for i in range(1, 9):
    X_init = np.load(f'{DATA_PATH}function_{i}_initial_inputs.npy')
    y_init = np.load(f'{DATA_PATH}function_{i}_initial_outputs.npy')
    
    past_x = np.array([hist_X[i][w] for w in range(4)])
    past_y = np.array([hist_Y[i][w] for w in range(4)])
    
    w5_x = np.array([week_5_submissions[i]["X"]])
    w5_y = np.array([week_5_submissions[i]["Y"]])
    
    X_combined = np.vstack((X_init, past_x, w5_x))
    y_combined = np.concatenate((y_init, past_y, w5_y))
    
    hist_X[i].append(week_5_submissions[i]["X"])
    hist_Y[i].append(week_5_submissions[i]["Y"])
    
    bounds = np.array([[0.0, 1.0]] * fn_dimensions[i])
    next_x = run_optimization_pipeline(X_combined, y_combined, bounds, n_restarts=10, xi=0.01)
    
    print(f"Function {i} ({fn_dimensions[i]}D) | Week 5 Max Y: {np.max(y_combined):.6e}")
    print(f" -> Next Suggested Target for Week 6: {np.round(next_x, 5)}\n")
