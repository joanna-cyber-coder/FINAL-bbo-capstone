# %%
# ==========================================
# WEEK 3: CONTINUIING INCREMENTAL MOVES
# ==========================================

# CHANGED: Processing Week 3 logs. The scores are trending well in low dimensions,
# but the high-dimensional functions (F7 and F8) are beginning to show signs of slowing down.
# We hold the line on the current architecture configuration to verify if the plateau is real.

print("--- Executing Week 3 Pipeline for All 8 Functions ---\n")

week_3_submissions = {
    1: {"X": [0.694321, 0.717345], "Y": 5.215757263549656e-9},
    2: {"X": [0.705000, 0.920000], "Y": 0.4990004717298282},
    3: {"X": [0.517500, 0.637500, 0.357500], "Y": -0.03137836381879529},
    4: {"X": [0.585000, 0.435000, 0.435000, 0.285000], "Y": -3.9191304392645416},
    5: {"X": [0.227500, 0.857500, 0.887500, 0.887500], "Y": 1220.9325419337779},
    6: {"X": [0.747500, 0.177500, 0.747500, 0.717500, 0.047500], "Y": -0.6606514681062613},
    7: {"X": [0.545000, 0.925000, 0.335000, 0.645000, 0.715000, 0.345000], "Y": 0.5497868872347305},
    8: {"X": [0.152500, 0.932500, 0.242500, 0.012500, 0.422500, 0.412500, 0.562500, 0.212500], "Y": 8.96856875}
}

for i in range(1, 9):
    X_init = np.load(f'{DATA_PATH}function_{i}_initial_inputs.npy')
    y_init = np.load(f'{DATA_PATH}function_{i}_initial_outputs.npy')
    
    past_x = np.array([hist_X[i][w] for w in range(2)])
    past_y = np.array([hist_Y[i][w] for w in range(2)])
    
    w3_x = np.array([week_3_submissions[i]["X"]])
    w3_y = np.array([week_3_submissions[i]["Y"]])
    
    X_combined = np.vstack((X_init, past_x, w3_x))
    y_combined = np.concatenate((y_init, past_y, w3_y))
    
    hist_X[i].append(week_3_submissions[i]["X"])
    hist_Y[i].append(week_3_submissions[i]["Y"])
    
    bounds = np.array([[0.0, 1.0]] * fn_dimensions[i])
    next_x = run_optimization_pipeline(X_combined, y_combined, bounds, n_restarts=10, xi=0.01)
    
    print(f"Function {i} ({fn_dimensions[i]}D) | Week 3 Max Y: {np.max(y_combined):.6e}")
    print(f" -> Next Suggested Target for Week 4: {np.round(next_x, 5)}\n")
